# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.font_manager import FontProperties
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm import tqdm
from transformers import (
    pipeline, 
    AutoTokenizer,
    AutoModelForSequenceClassification
)
import warnings
warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %matplotlib inline

# %%
# report style 設定
plt.style.use('ggplot')
fontproperties = FontProperties(fname='font_ch.ttf', size=14)
font = 'font_ch.ttf'
stopword_file_zhTW = 'stopwords_zhTW.txt'

# %%
# Initialize drivers
ws_driver = CkipWordSegmenter(level=3, device=0)

# Initialize TfidfVectorizer
vectorizer = TfidfVectorizer()

# 加載 RoBERTa-base chinese fine-tuned model (for text classification) - https://huggingface.co/uer/roberta-base-finetuned-jd-full-chinese
tokenizer = AutoTokenizer.from_pretrained('uer/roberta-base-finetuned-jd-full-chinese')
model = AutoModelForSequenceClassification.from_pretrained('uer/roberta-base-finetuned-jd-full-chinese')
# test the pretrained model
sentiment_classifier = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
res = sentiment_classifier('要买就买贵的不想比来比去，做工、效果非常好，不用出门在家减脂瑜伽都可以！')
print(res[0]['label'][-1])
# Out:
# 5

# %%
print('Loading Traditional Chinese stopwords...')
stopwords_zhTW = list()
with open(stopword_file_zhTW, 'r', encoding='utf-8') as f:
    for l in tqdm(f.readlines()):
        if not len(l.strip()):
            continue
        stopwords_zhTW.append(l.strip())

stopwords_zhTW += ['想','請問','收到','剛剛']
# Out:
# Loading Traditional Chinese stopwords...
# 100%|██████████| 2870/2870 [00:00<00:00, 602756.62it/s]

# %%
data = pd.read_csv('chatbot_data_seg.csv', error_bad_lines=False)
data = data[data['re'].notnull()].reset_index(drop=True)

# data['類目'].value_counts().reset_index().sort_values('類目', ascending=False)
# data.head(5)
data[data['Question'].str.contains('信用卡')]
# data[data['標註']!='0']
# data.info()
# data.isnull().sum()
# Out:
# b'Skipping line 6000: expected 19 fields, saw 35\nSkipping line 9001: expected 19 fields, saw 23\nSkipping line 15013: expected 19 fields, saw 32\nSkipping line 18014: expected 19 fields, saw 32\n'
# b'Skipping line 32963: expected 19 fields, saw 24\nSkipping line 38962: expected 19 fields, saw 35\nSkipping line 41963: expected 19 fields, saw 23\nSkipping line 47975: expected 19 fields, saw 32\nSkipping line 50976: expected 19 fields, saw 32\n'
#                   Question                   Intent   FAQ_Answer1  \
# 4              想問信用卡可不可以使用                 fallback  申辦信用卡是否一定能核發
# 9                  信用卡電話更改                 fallback     修改信用卡通訊資料
# 15                   信用卡核准                 fallback        卡片寄出時間
# 17                信用卡 健康檢查                 fallback      紅利點數兌換方式
# 19     請問刷國泰世華的信用卡繳保險可以分期嗎        installment.apply    信用卡繳保費分期說明
# ...                    ...                      ...           ...
# 66303             差不到有效信用卡                 fallback     信用卡到期續卡方式
# 66309              信用卡無法感應                 fallback       毀損補發信用卡
# 66337              我的信用卡卡號  creditLimit.queryAmount      信用卡卡號或效期
# 66341          信用卡中獎發票如何領取                 fallback   電子發票信用卡載具功能
# 66343        可麻煩重寄本期信用卡帳單嗎                 fallback     信用卡繳款入帳時間
#
#          FAQ_Answer2  FAQ_Answer3                       阿發會出現什麼           標註  \
# 4            信用卡扣繳保費  學生申請信用卡額度調高                  申辦信用卡是否一定能核發            0
# 9           修改資料相關問題     國泰世華客服專線                     修改信用卡通訊資料            0
# 15         申請信用卡天數說明     信用貸款申請進度                        卡片寄出時間            0
# 17            無法刷卡原因         身體健康                      紅利點數兌換方式            0
# 19           信用卡扣繳保費       分期產品介紹  installment.apply,信用卡繳保費分期說明            0
# ...              ...          ...                           ...          ...
# 66303       信用卡卡號或效期       國外預借現金                     信用卡到期續卡方式            0
# 66309         無法刷卡原因      感應式交易功能                       毀損補發信用卡      毀損補發信用卡
# 66337  ATM轉帳繳信用卡帳單方式      申請停用信用卡                      信用卡卡號或效期     信用卡卡號或效期
# 66341    信用卡電子發票中獎通知  電子發票存入信用卡方式                   電子發票信用卡載具功能  電子發票信用卡載具功能
# 66343  信用卡正附卡帳單如何分開寄    查詢信用卡消費金額                     信用卡繳款入帳時間            0
#
#           new_label             類目 cat1 cat2    cat3 cat4 cat_new  main_id  \
# 4      申辦信用卡是否一定能核發    信用卡|業務|卡片申請  信用卡   業務    卡片申請    無  信用卡-業務    21193
# 9         修改信用卡通訊資料         信用卡|業務  信用卡   業務       無    無  信用卡-業務    21192
# 15           卡片寄出時間         信用卡|業務  信用卡   業務       無    無  信用卡-業務     2209
# 17         紅利點數兌換方式         信用卡|業務  信用卡   業務       無    無  信用卡-業務    17725
# 19       信用卡繳保費分期說明   信用卡|業務|分期|活動  信用卡   業務      分期   活動  信用卡-業務    19760
# ...             ...            ...  ...  ...     ...  ...     ...      ...
# 66303     信用卡到期續卡方式         信用卡|業務  信用卡   業務       無    無  信用卡-業務    34329
# 66309       毀損補發信用卡         信用卡|卡片  信用卡   卡片       無    無  信用卡-卡片    34540
# 66337      信用卡卡號或效期         信用卡|業務  信用卡   業務       無    無  信用卡-業務    35346
# 66341   電子發票信用卡載具功能         信用卡|業務  信用卡   業務       無    無  信用卡-業務    35507
# 66343     信用卡繳款入帳時間  信用卡|業務|帳單繳費相關  信用卡   業務  帳單繳費相關    無  信用卡-業務    35564
#
#        labelencoder                        id                   re  \
# 4                26    21193-@--@-信用卡|業務|卡片申請          想問信用卡可不可以使用
# 9                22         21192-@--@-信用卡|業務              信用卡電話更改
# 15               22          2209-@--@-信用卡|業務                信用卡核准
# 17               22         17725-@--@-信用卡|業務              信用卡健康檢查
# 19               25   19760-@--@-信用卡|業務|分期|活動  請問刷國泰世華的信用卡繳保險可以分期嗎
# ...             ...                       ...                  ...
# 66303            22         34329-@--@-信用卡|業務             差不到有效信用卡
# 66309             6         34540-@--@-信用卡|卡片              信用卡無法感應
# 66337            22         35346-@--@-信用卡|業務              我的信用卡卡號
# 66341            22         35507-@--@-信用卡|業務          信用卡中獎發票如何領取
# 66343            27  35564-@--@-信用卡|業務|帳單繳費相關        可麻煩重寄本期信用卡帳單嗎
#
#                                seg
# 4                    ['想問', '信用卡']
# 9              ['信用卡', '電話', '更改']
# 15                   ['信用卡', '核准']
# 17             ['信用卡', '健康', '檢查']
# 19     ['問刷國', '泰世華', '信用卡', '保險']
# ...                            ...
# 66303               ['差不到', '信用卡']
# 66309          ['信用卡', '無法', '感應']
# 66337                ['信用卡', '卡號']
# 66341    ['信用卡', '中獎', '發票', '領取']
# 66343     ['可麻煩', '重寄本期', '信用卡帳單']
#
# [7390 rows x 19 columns]

# %%
sent_list = data.re.values
# word_list = ws_driver(sent_list, use_delim=True)

# %%
cat_list = list()
for i in range(len(data)):
    try:
        cat_list += data['類目'][i].split('|')
    except:
        cat_list += ['']
        print(data['類目'][i])

cat_list[:5]
# Out:
# Tokenization: 100%|██████████| 66350/66350 [00:01<00:00, 43953.49it/s]
# Inference: 100%|██████████| 260/260 [02:02<00:00,  2.12it/s]
# ['信用卡', '卡片', 'KOKO(PLAY/NBA)', '銀行', '理財投資']

# %%
def getSentimentScore(sent):
    _ = sentiment_classifier(sent)
    label = _[0]['label']
    score = _[0]['score']

sentiment_list = list()
for sent in tqdm(sent_list):
    try:
        sentiment_list.append(sentiment_classifier(sent))
    except:
        print(sent)
        sentiment_list.append((0.0, 0.0))

sentiment_list[:10]
# Out:
# 100%|██████████| 66350/66350 [26:20<00:00, 41.97it/s]
# [[{'label': 'star 4', 'score': 0.3821466565132141}],
#  [{'label': 'star 4', 'score': 0.42447739839553833}],
#  [{'label': 'star 1', 'score': 0.43302515149116516}],
#  [{'label': 'star 1', 'score': 0.24196097254753113}],
#  [{'label': 'star 2', 'score': 0.2655748724937439}],
#  [{'label': 'star 1', 'score': 0.6410739421844482}],
#  [{'label': 'star 2', 'score': 0.3717615604400635}],
#  [{'label': 'star 1', 'score': 0.37669193744659424}],
#  [{'label': 'star 4', 'score': 0.4177226126194}],
#  [{'label': 'star 1', 'score': 0.2921123504638672}]]

# %%
df_kw_sent = pd.DataFrame({
    'keyword': data['類目'].values.tolist(), 
    'sentiment': [item[0]['label'][-1] for item in sentiment_list],
    'confidence': [round(float(item[0]['score']), 3) for item in sentiment_list],
})
df_kw_sent.head()
df_kw_sent['sentiment'] = df_kw_sent['sentiment'].astype(int)
df_kw_sent = df_kw_sent.drop('keyword', axis=1).join(df_kw_sent['keyword']
                                                    .str
                                                    .split('|', expand=True)
                                                    .stack()
                                                    .reset_index(drop=True, level=1)
                                                    .rename('keyword'))
df_kw_sent = df_kw_sent.drop('keyword', axis=1).join(df_kw_sent['keyword']
                                                    .str
                                                    .split(',', expand=True)
                                                    .stack()
                                                    .reset_index(drop=True, level=1)
                                                    .rename('keyword'))
df_kw_sent = df_kw_sent.groupby(['keyword']).agg({'keyword': 'count', 'sentiment': 'mean', 'confidence': 'mean'}).rename(columns={'keyword': 'count'})
df_kw_sent['x'] = np.random.random(df_kw_sent.shape[0])
df_kw_sent['y'] = np.random.random(df_kw_sent.shape[0])
for col in df_kw_sent.columns[1:]:
    df_kw_sent[col] = df_kw_sent[col].apply(lambda x: (x - np.min(df_kw_sent[col])) / (np.max(df_kw_sent[col]) - np.min(df_kw_sent[col])))
df_kw_sent['count'] = np.log(df_kw_sent['count']) * 1000
df_kw_sent = df_kw_sent.reset_index()
df_kw_sent.sort_values('sentiment')
# Out:
#                  keyword sentiment  confidence
# 0  信用卡|卡片|KOKO(PLAY/NBA)         4       0.382
# 1             銀行|理財投資|基金         4       0.424
# 2          信用卡|業務|帳單繳費相關         1       0.433
# 3                  銀行|業務         1       0.242
# 4            信用卡|業務|卡片申請         2       0.266
#    keyword        count  sentiment  confidence         x         y
# 17      保險  1386.294361   0.000000    0.461244  0.678665  0.681970
# 2       閒聊  1791.759469   0.000000    0.050078  0.970261  0.693379
# 40      春節  1386.294361   0.250000    0.000000  0.078815  0.911518
# 37      收單  4510.859507   0.269231    0.280048  0.483046  0.681179
# 51    行動銀行  6419.994928   0.274430    0.265663  0.952665  0.246609
# ..     ...          ...        ...         ...       ...       ...
# 1       優惠   693.147181   0.750000    0.590392  0.361309  0.442238
# 0      信用卡   693.147181   0.750000    0.590392  0.971496  0.358201
# 54    貴賓權益  3465.735903   0.781250    0.689230  0.135534  0.950342
# 30    基金投資  2995.732274   0.800000    0.360034  0.383014  0.661397
# 38      新年   693.147181   1.000000    0.326824  0.033546  0.400013
#
# [65 rows x 6 columns]

# %%
fig = px.scatter(df_kw_sent, x='x', y='y', size='count', color='sentiment', 
                 opacity=df_kw_sent['confidence'].values, text='keyword', size_max=19, height=1000, width=1000)
fig.show()
# Out:
# <div>                            <div id="be1d1442-8b69-4ec9-acc6-11101a34f657" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be1d1442-8b69-4ec9-acc6-11101a34f657")) {                    Plotly.newPlot(                        "be1d1442-8b69-4ec9-acc6-11101a34f657",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>count=%{marker.size}<br>keyword=%{text}<br>sentiment=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.75,0.75,0.0,0.2932692307692307,0.39460214053047926,0.5329601990049752,0.41860465116279066,0.4321030640668524,0.5914713541666666,0.5836673346693386,0.5847826086956521,0.30454545454545456,0.6924882629107981,0.6805555555555556,0.6666666666666666,0.5833333333333334,0.5648854961832062,0.0,0.40914017021427185,0.5637795275590551,0.6797034764826176,0.5817757009345794,0.4289786812097174,0.47243984331281474,0.5467180326378471,0.4703224230581339,0.45634633911368017,0.6100136239782016,0.41201716738197425,0.549407114624506,0.8,0.6988636363636364,0.5085818307905686,0.6984702093397746,0.28789882272649714,0.5595637583892618,0.4409448818897638,0.2692307692307693,1.0,0.42391304347826086,0.25,0.6396396396396397,0.3516086575021936,0.5926451331296377,0.5696392785571143,0.4650706436420722,0.42678958785249455,0.36002962336013544,0.4230570839064649,0.3786127167630058,0.529126213592233,0.2744299674267101,0.7280966767371602,0.5621323529411765,0.78125,0.44999999999999996,0.30662348516506477,0.5833333333333334,0.4550140845070423,0.4614164904862579,0.6171328671328671,0.47815533980582525,0.4898190045248869,0.46111111111111114,0.5441176470588235],"coloraxis":"coloraxis","opacity":[0.5903917575176711,0.5903917575176711,0.05007787228944536,0.4228234925491426,0.25087136296102136,0.2779361250534199,0.6215908236074235,0.254544774981287,0.2848899679525578,0.2779926691768586,0.3463051031091619,0.3493470708038816,0.5575014722334246,0.255660716425063,0.9954075316480973,0.9883790583443153,0.3064628970320734,0.4612435605606805,0.29544276512269657,0.45328464467878987,0.3616749337396923,0.3745864259250343,0.2905883433964532,0.2007765797946991,0.3076018577861778,0.2669527982901399,0.27137003983986513,0.33983003568969783,0.18239340700135898,0.4290789192680526,0.36003354498622264,1.0,0.40075640720369776,0.45313280423004826,0.29571168187772123,0.21622284419994164,0.25788132659289165,0.2800479740697783,0.32682400862585365,0.5893604054567901,0.0,0.3312880389674448,0.28622279607685003,0.333126165450076,0.41344747719951713,0.24256921944713972,0.33075751429261224,0.21321325873641714,0.3136120860825386,0.5058977265723522,0.3165883678921908,0.2656625544530424,0.8182146234857613,0.19897814642809325,0.6892296633521027,0.435179638725823,0.25513203895131414,0.9883790583443153,0.3059013325188944,0.31630846342231317,0.3386200477370959,0.3334132023481491,0.30456982675109656,0.1575549432264421,0.6028983056023416],"size":[693.1471805599452,693.1471805599452,1791.759469228055,4644.390899141373,8365.905077202457,7788.211557847076,6246.106765481562,7675.081857716334,7336.936913707617,7311.218384419629,4744.93212836325,5799.092654460525,6054.439346269371,6068.42558824411,3583.51893845611,2484.9066497880003,4875.197323201151,1386.2943611198905,11635.44393739343,7146.772179452637,8831.419819090132,5771.4411231300155,7609.366537954212,8586.905803827538,9998.752276761908,8722.742874329399,9024.492605405669,7697.121317282626,6144.185634125645,7325.148957955575,2995.732273553991,5575.949103146316,8660.080678964785,8223.090551161533,10467.834985704485,6795.705775173514,7329.093736246592,4510.85950651685,693.1471805599452,3135.4942159291495,1386.2943611198905,5402.6773818722795,11355.979214507503,9346.181594887597,6905.753276311464,7555.381944240273,6826.545223556594,8460.834457746854,7975.22083865341,6251.903883165888, ...

# %%
fig = px.scatter(df_kw_sent, x='confidence', y='sentiment', size='count', color='sentiment', 
                 opacity=df_kw_sent['confidence'].values, 
                 text='keyword', height=1000, width=1000)
fig.show()
# Out:
# <div>                            <div id="2a00a0a5-8f61-4434-b8c1-5e1570bdf41e" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a00a0a5-8f61-4434-b8c1-5e1570bdf41e")) {                    Plotly.newPlot(                        "2a00a0a5-8f61-4434-b8c1-5e1570bdf41e",                        [{"hovertemplate":"confidence=%{x}<br>sentiment=%{marker.color}<br>count=%{marker.size}<br>keyword=%{text}<extra></extra>","legendgroup":"","marker":{"color":[0.75,0.75,0.0,0.2932692307692307,0.39460214053047926,0.5329601990049752,0.41860465116279066,0.4321030640668524,0.5914713541666666,0.5836673346693386,0.5847826086956521,0.30454545454545456,0.6924882629107981,0.6805555555555556,0.6666666666666666,0.5833333333333334,0.5648854961832062,0.0,0.40914017021427185,0.5637795275590551,0.6797034764826176,0.5817757009345794,0.4289786812097174,0.47243984331281474,0.5467180326378471,0.4703224230581339,0.45634633911368017,0.6100136239782016,0.41201716738197425,0.549407114624506,0.8,0.6988636363636364,0.5085818307905686,0.6984702093397746,0.28789882272649714,0.5595637583892618,0.4409448818897638,0.2692307692307693,1.0,0.42391304347826086,0.25,0.6396396396396397,0.3516086575021936,0.5926451331296377,0.5696392785571143,0.4650706436420722,0.42678958785249455,0.36002962336013544,0.4230570839064649,0.3786127167630058,0.529126213592233,0.2744299674267101,0.7280966767371602,0.5621323529411765,0.78125,0.44999999999999996,0.30662348516506477,0.5833333333333334,0.4550140845070423,0.4614164904862579,0.6171328671328671,0.47815533980582525,0.4898190045248869,0.46111111111111114,0.5441176470588235],"coloraxis":"coloraxis","opacity":[0.5903917575176711,0.5903917575176711,0.05007787228944536,0.4228234925491426,0.25087136296102136,0.2779361250534199,0.6215908236074235,0.254544774981287,0.2848899679525578,0.2779926691768586,0.3463051031091619,0.3493470708038816,0.5575014722334246,0.255660716425063,0.9954075316480973,0.9883790583443153,0.3064628970320734,0.4612435605606805,0.29544276512269657,0.45328464467878987,0.3616749337396923,0.3745864259250343,0.2905883433964532,0.2007765797946991,0.3076018577861778,0.2669527982901399,0.27137003983986513,0.33983003568969783,0.18239340700135898,0.4290789192680526,0.36003354498622264,1.0,0.40075640720369776,0.45313280423004826,0.29571168187772123,0.21622284419994164,0.25788132659289165,0.2800479740697783,0.32682400862585365,0.5893604054567901,0.0,0.3312880389674448,0.28622279607685003,0.333126165450076,0.41344747719951713,0.24256921944713972,0.33075751429261224,0.21321325873641714,0.3136120860825386,0.5058977265723522,0.3165883678921908,0.2656625544530424,0.8182146234857613,0.19897814642809325,0.6892296633521027,0.435179638725823,0.25513203895131414,0.9883790583443153,0.3059013325188944,0.31630846342231317,0.3386200477370959,0.3334132023481491,0.30456982675109656,0.1575549432264421,0.6028983056023416],"size":[693.1471805599452,693.1471805599452,1791.759469228055,4644.390899141373,8365.905077202457,7788.211557847076,6246.106765481562,7675.081857716334,7336.936913707617,7311.218384419629,4744.93212836325,5799.092654460525,6054.439346269371,6068.42558824411,3583.51893845611,2484.9066497880003,4875.197323201151,1386.2943611198905,11635.44393739343,7146.772179452637,8831.419819090132,5771.4411231300155,7609.366537954212,8586.905803827538,9998.752276761908,8722.742874329399,9024.492605405669,7697.121317282626,6144.185634125645,7325.148957955575,2995.732273553991,5575.949103146316,8660.080678964785,8223.090551161533,10467.834985704485,6795.705775173514,7329.093736246592,4510.85950651685,693.1471805599452,3135.4942159291495,1386.2943611198905,5402.6773818722795,11355.979214507503,9346.181594887597,6905.753276311464,7555.381944240273,6826.545223556594,8460.834457746854,7975.22083865341,6251.903883165888,6 ...

# %%
# data[data['類目'].str.contains('保險|閒聊')].head(5)
data[data['類目'].str.contains('新年|外匯|人臉')].head(30)

# 能否有時間流？ 知道用戶是否因為回覆文不對題而離開
# 是否知道用戶有無點擊阿發出現的資訊卡
# 計算回覆和提問的相似度
# Out:
#            Question             Intent      FAQ_Answer1   FAQ_Answer2  \
# 3449         拒絕人臉辨識  installment.apply           人臉辨識介紹        人臉辨識功能
# 11682        登入方式設定           fallback  設定及使用人臉登入行動銀行方式  設定網路安全認證密碼方式
# 23566      我沒做人臉辨識阿    bank.turnToReal           人臉辨識介紹        人臉辨識功能
# 27002          人臉辨識  installment.apply           人臉辨識介紹        人臉辨識功能
# 30405          人像辨識  installment.apply           人臉辨識介紹      人臉辨識申請方式
# 32549  KOKO調整轉帳金額限制           fallback   KOKO使用人臉轉帳手機版本      KOKO轉帳介紹
# 36403        拒絕人臉辨識  installment.apply           人臉辨識介紹        人臉辨識功能
# 44636        登入方式設定           fallback  設定及使用人臉登入行動銀行方式  設定網路安全認證密碼方式
# 56520      我沒做人臉辨識阿    bank.turnToReal           人臉辨識介紹        人臉辨識功能
# 59956          人臉辨識  installment.apply           人臉辨識介紹        人臉辨識功能
# 63359          人像辨識  installment.apply           人臉辨識介紹      人臉辨識申請方式
# 65503  KOKO調整轉帳金額限制           fallback   KOKO使用人臉轉帳手機版本      KOKO轉帳介紹
#
#       FAQ_Answer3                   阿發會出現什麼 標註        new_label          類目  \
# 3449     人臉辨識申請方式  installment.apply,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 11682   約定帳戶的設定方法           設定及使用人臉登入行動銀行方式  0  設定及使用人臉登入行動銀行方式  銀行|業務|人臉辨識
# 23566    人臉辨識申請方式    bank.turnToReal,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 27002    人臉辨識申請方式  installment.apply,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 30405      人臉辨識功能  installment.apply,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 32549  KOKO數位帳戶介紹            KOKO使用人臉轉帳手機版本  0   KOKO使用人臉轉帳手機版本  銀行|業務|人臉辨識
# 36403    人臉辨識申請方式  installment.apply,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 44636   約定帳戶的設定方法           設定及使用人臉登入行動銀行方式  0  設定及使用人臉登入行動銀行方式  銀行|業務|人臉辨識
# 56520    人臉辨識申請方式    bank.turnToReal,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 59956    人臉辨識申請方式  installment.apply,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 63359      人臉辨識功能  installment.apply,人臉辨識介紹  0           人臉辨識介紹  銀行|業務|人臉辨識
# 65503  KOKO數位帳戶介紹            KOKO使用人臉轉帳手機版本  0   KOKO使用人臉轉帳手機版本  銀行|業務|人臉辨識
#
#       cat1 cat2  cat3 cat4 cat_new  main_id  labelencoder  \
# 3449    銀行   業務  人臉辨識    無   銀行-業務    21427            64
# 11682   銀行   業務  人臉辨識    無   銀行-業務    21636            64
# 23566   銀行   業務  人臉辨識    無   銀行-業務    27793            64
# 27002   銀行   業務  人臉辨識    無   銀行-業務    28082            64
# 30405   銀行   業務  人臉辨識    無   銀行-業務    15114            64
# 32549   銀行   業務  人臉辨識    無   銀行-業務    25667            64
# 36403   銀行   業務  人臉辨識    無   銀行-業務    21427            64
# 44636   銀行   業務  人臉辨識    無   銀行-業務    21636            64
# 56520   銀行   業務  人臉辨識    無   銀行-業務    27793            64
# 59956   銀行   業務  人臉辨識    無   銀行-業務    28082            64
# 63359   銀行   業務  人臉辨識    無   銀行-業務    15114            64
# 65503   銀行   業務  人臉辨識    無   銀行-業務    25667            64
#
#                           id            re                         seg
# 3449   21427-@--@-銀行|業務|人臉辨識        拒絕人臉辨識               ['拒絕', '臉辨識']
# 11682  21636-@--@-銀行|業務|人臉辨識        登入方式設定          ['登入', '方式', '設定']
# 23566  27793-@--@-銀行|業務|人臉辨識      我沒做人臉辨識阿                     ['臉辨識']
# 27002  28082-@--@-銀行|業務|人臉辨識          人臉辨識                ['人臉', '辨識']
# 30405  15114-@--@-銀行|業務|人臉辨識          人像辨識                ['人像', '辨識']
# 32549  25667-@--@-銀行|業務|人臉辨識  KOKO調整轉帳金額限制  ['KOKO', '調整', '轉帳', '金額']
# 36403  21427-@--@-銀行|業務|人臉辨識        拒絕人臉辨識               ['拒絕', '臉辨識']
# 44636  21636-@--@-銀行|業務|人臉辨識        登入方式設定          ['登入', '方式', '設定']
# 56520  27793-@--@-銀行|業務|人臉辨識      我沒做人臉辨識阿                     ['臉辨識']
# 59956  28082-@--@-銀行|業務|人臉辨識          人臉辨識                ['人臉', '辨識']
# 63359  15114-@--@-銀行|業務|人臉辨識          人像辨識                ['人像', '辨識']
# 65503  25667-@--@-銀行|業務|人臉辨識  KOKO調整轉帳金額限制  ['KOKO', '調整', '轉帳', '金額']

# %%
ws_nostopwords = list()
for wl in tqdm(word_list):
    ws_nostopwords.append([w for w in wl if w not in stopwords_zhTW])
word_list = ws_nostopwords.copy()
# ws_nostopwords = list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3839292/3186154863.py in <module>
#       1 ws_nostopwords = list()
# ----> 2 for wl in tqdm(word_list):
#       3     ws_nostopwords.append([w for w in wl if w not in stopwords_zhTW])
#       4 word_list = ws_nostopwords.copy()
#       5 # ws_nostopwords = list()
#
# NameError: name 'word_list' is not defined

# %%
from collections import Counter

def makeCounter(word_list):
    counter = dict()
    for wl in word_list:
        for k, v in dict(Counter(wl)).items():
            if k not in counter.keys():
                counter.update({k: v})
            else:
                counter.update({k: counter[k] + v})

    return counter

# counter = makeCounter(word_list=word_list)
cat_counter = Counter(cat_list)
cat_counter
# Out:
# Counter({'信用卡': 41463,
#          '卡片': 7316,
#          'KOKO(PLAY/NBA)': 499,
#          '銀行': 18794,
#          '理財投資': 330,
#          '基金': 500,
#          '業務': 31801,
#          '帳單繳費相關': 11722,
#          '卡片申請': 2047,
#          '年費規則': 298,
#          '網路銀行': 2361,
#          '活動': 3482,
#          '優惠': 2975,
#          '分期': 1523,
#          '繳費繳稅(代扣繳)': 933,
#          '外匯存款': 2884,
#          'ATM金融卡': 2094,
#          '專屬優惠': 1242,
#          '台幣業務': 4152,
#          '信託業務': 544,
#          '閒聊': 3696,
#          'KOKO': 619,
#          '費用類': 2393,
#          '電子票證': 618,
#          '一卡通': 108,
#          '票據業務': 461,
#          'VIP': 213,
#          'I刷': 718,
#          '其他': 2017,
#          '回饋方式': 734,
#          '優惠權益': 107,
#          '悠遊卡': 381,
#          '行動支付': 276,
#          '收單': 91,
#          '表單下載': 230,
#          '申辦方法': 637,
#          '國泰優惠': 233,
#          'MY ATM': 110,
#          'COSTCO卡': 804,
#          'ICASH': 129,
#          '貸款': 900,
#          '雙幣卡': 143,
#          '首刷禮': 51,
#          '貴賓室': 680,
#          '聯徵、強停': 173,
#          '預借現金產品': 221,
#          '智能投資': 102,
#          '行動銀行': 307,
#          '企金': 131,
#          '新聞相關事件': 23,
#          'LINE': 115,
#          'ATM': 46,
#          '額度': 90,
#          '人臉辨識': 12,
#          '外匯': 88,
#          '超商': 6,
#          '代收': 6,
#          '基金投資': 10,
#          '貴賓權益': 16,
#          '春節': 4,
#          '保險': 2,
#          '活動, 信用卡, 優惠': 2,
#          '繳費繳稅(代扣繳), 閒聊': 2,
#          '新年': 2})

# %%
ws_tfidf_vector = vectorizer.fit_transform([' '.join(w) for w in word_list])
print(vectorizer.get_feature_names()[:10])
print(vectorizer.get_feature_names()[-10:])
print(ws_tfidf_vector.shape)
# Out:
# ['0000', '004', '0050', '006', '007', '008', '0081131', '009', '0102', '0104']
# ['鼓勵', '龍勝', '龍卡', '龍腾卡', '龍騰', '龍騰卡', '龍騰卡號', '龍騰卡邦卡', '龍鰧', '龍鰧卡']
# (66350, 4989)

# %%
ws_tfidf_vector = ws_tfidf_vector.toarray()
avg_tfidf_by_word = list()
for i in tqdm(range(ws_tfidf_vector.shape[1])):
    avg_tfidf_by_word.append(ws_tfidf_vector[:, i].sum())
# Out:
# 100%|██████████| 4989/4989 [00:06<00:00, 793.08it/s]

# %%
word_tfidf_dict = dict(zip(vectorizer.get_feature_names(), avg_tfidf_by_word))

# %%
wc = WordCloud(background_color='white', max_words=ws_tfidf_vector.shape[1], font_path=font, width=400, height=300)
wc.generate_from_frequencies(word_tfidf_dict)
plt.figure(figsize=(12, 9))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.savefig('afa_question_wordcloud_tfidf.jpg')
plt.show()
# Out:
# (-0.5, 399.5, 299.5, -0.5)

# %%
wc = WordCloud(background_color='white', max_words=len(counter.keys()), font_path=font, width=500, height=300)
wc.generate_from_frequencies(counter)
plt.figure(figsize=(14, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# (-0.5, 499.5, 299.5, -0.5)

# %%
wc = WordCloud(background_color='white', max_words=len(cat_counter.keys()), font_path=font, width=500, height=300)
wc.generate_from_frequencies(cat_counter)
plt.figure(figsize=(14, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# (-0.5, 499.5, 299.5, -0.5)

# %%
df_tfidf = pd.DataFrame(word_tfidf_dict.items(), columns=['keyword', 'importance']).sort_values('importance')

# %%
import plotly.express as px

fig = px.bar(df_tfidf.tail(30), 
             x='importance', y='keyword', orientation='h', height=1000, width=500)
fig.show()
# Out:
# <div>                            <div id="33e2dbc9-5c39-4918-a4aa-ac769a2ac4ff" class="plotly-graph-div" style="height:1000px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33e2dbc9-5c39-4918-a4aa-ac769a2ac4ff")) {                    Plotly.newPlot(                        "33e2dbc9-5c39-4918-a4aa-ac769a2ac4ff",                        [{"alignmentgroup":"True","hovertemplate":"importance=%{x}<br>keyword=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[520.4243817401866,530.9942150557321,537.3985158069619,549.081840186415,553.6707115939524,563.872424379985,570.8522343838608,594.6216292866304,598.5000512720732,607.2039677533063,615.9953130384841,620.9899854029851,622.2821201427018,628.4617983481442,655.8217754645522,665.3655934439956,700.5244709915712,751.6526078462628,764.3802455392982,804.9136274942498,845.3243476105189,954.5787776348684,1001.5856060035946,1068.8947657312651,1083.0133980792941,1159.6307369126544,1362.5457732679133,1372.033954963939,1585.6359878960452,2847.2706067196764],"xaxis":"x","y":["\u4fdd\u8cbb","\u570b\u5916","\u6263\u6b3e","\u5165\u5e33","\u570b\u6cf0","\u91d1\u878d\u5361","\u66f4\u6539","\u7dda\u4e0a","\u91d1\u984d","\u5e33\u865f","\u5e74\u8cbb","\u5b9a\u5b58","\u9280\u884c","\u96fb\u8a71","\u5916\u5e63","\u56de\u994b","\u660e\u7d30","\u5e33\u6236","\u512a\u60e0","\u624b\u7e8c\u8cbb","\u5bc6\u78bc","\u7533\u8acb","\u67e5\u8a62","\u6d88\u8cbb","\u8f49\u5e33","\u7e73\u6b3e","\u7e73\u8cbb","\u5237\u5361","\u5e33\u55ae","\u4fe1\u7528\u5361"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...
